# %% [markdown]
# # OARS Colab MVP
# End-to-end pipeline: prepare, validate, ablate, plot, stats.

# %%
# !git clone https://github.com/PAMF2/oars-colab-mvp.git
# %cd oars-colab-mvp
# !pip -q install -e .[dev]

# %%
# Optional: upload your own raw file
# from google.colab import files
# files.upload()  # ex: minif2f_raw.jsonl

# %%
# !python scripts/run_full_pipeline.py --epochs 30 --seeds 7 --samples 5000

# %%
# !oars-mvp stats --csv outputs/ablation_summary.csv

# %%
from IPython.display import Image, display
display(Image('outputs/plots/acc_mean.png'))
display(Image('outputs/plots/reward_mean.png'))
display(Image('outputs/plots/entropy_mean.png'))
display(Image('outputs/plots/runtime_mean.png'))
