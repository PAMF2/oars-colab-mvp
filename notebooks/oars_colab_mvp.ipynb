# %% [markdown]
# # OARS Colab MVP\nMVP para validar ablações baseline/hierarchical/ARLA em setup leve.

# %%
# !git clone https://github.com/PAMF2/oars-colab-mvp.git\n%cd oars-colab-mvp\n!pip -q install -r requirements.txt

# %%
# !python scripts/run_ablation.py --epochs 3 --samples 1200 --seeds 3

# %%
import pandas as pd\ndf = pd.read_csv('outputs/ablation_summary.csv')\ndf.groupby('mode')[['acc','reward','allocator_entropy','runtime_sec']].mean().sort_values('acc', ascending=False)

# %%
df
