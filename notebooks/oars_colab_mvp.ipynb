# %% [markdown]
# # OARS Colab MVP
# Ablation runner + optional W&B + miniF2F raw-data preparation + auto plots.

# %%
# !git clone https://github.com/PAMF2/oars-colab-mvp.git
# %cd oars-colab-mvp
# !pip -q install -r requirements.txt

# %% [markdown]
# ## Optional: upload raw miniF2F-like JSONL and prepare features

# %%
# from google.colab import files
# files.upload()  # upload minif2f_raw.jsonl
# !python scripts/prepare_minif2f.py --input minif2f_raw.jsonl --output data/minif2f_prepared.jsonl --write-split

# %% [markdown]
# ## Optional: enable W&B

# %%
# !wandb login

# %%
# Default config uses synthetic data.
# To use prepared miniF2F-like data, edit configs/default.yaml dataset.type/path first.
# !python scripts/run_ablation.py --epochs 3 --samples 1200 --seeds 3

# %%
# !python scripts/plot_results.py --csv outputs/ablation_summary.csv

# %%
import pandas as pd
df = pd.read_csv('outputs/ablation_summary.csv')
df.groupby('mode')[['acc','reward','allocator_entropy','runtime_sec']].mean().sort_values('acc', ascending=False)

# %%
from IPython.display import Image, display
display(Image('outputs/plots/acc_mean.png'))
display(Image('outputs/plots/reward_mean.png'))
display(Image('outputs/plots/entropy_mean.png'))
display(Image('outputs/plots/runtime_mean.png'))
